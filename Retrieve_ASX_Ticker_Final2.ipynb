# %% [markdown]
# ### Codes to read directly from Market Index website
# ##### Put into dataframe
# ###### Do some data cleaning
# ######  1. Get rid of $ and convert to float from Price Column
# ######  2. Get rid of + and % and convert to float from 1 Day Column
# ######  3. Get rid of + and % and convert to float from 1 Week Column
# ######  4. Get rid of + and % and convert to float from 1 Month Column
# ######  5. Get rid of + and % and convert to float from 1 Year Column
# ###### Export the clean data to CSV.

# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
from pathlib import Path
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
from datetime import datetime  

import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Find all the data pertaining to ASX tickers listed in this website.
#
# https://www.marketindex.com.au/asx-listed-companies

# %% [markdown]
# #### Codes to rerieve all the ASX data direct from Market Index website and put into dataframe

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup

# Set up Splinter
browser = Browser('chrome')

# Define the URL of the website you want to scrape
url = "https://www.marketindex.com.au/asx-listed-companies"

# Use Splinter to open the URL
browser.visit(url)

# Get the HTML content from the page
html_content = browser.html

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Extract and print the head section
print(soup.head)
# Out:
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="nvgG8tWeJU6cz7ig1T2tM1hdLGBYJOr9Fvf4oN7I" name="csrf-token"/>
# <title>ASX Listed Companies (Full List) - Market Index</title>
# <meta content="Full list of ASX companies ranked by size. Sort alphabetically, by performance or market cap. Link to all company details and price history." name="description"/>
# <link href="https://www.marketindex.com.au/asx-listed-companies" rel="canonical"/>
# <link as="style" href="/css/app.css?id=49cf098fae2e50c34bde0c8906cf40f5" rel="preload"/>
# <link as="script" href="/js/manifest.js?id=b4e8ee4a51ac7521ace11ee205df0da6" rel="preload"/>
# <link as="script" href="/js/vendor.js?id=3e8738535a5ac8b318dd620a4a90d0c8" rel="preload"/>
# <link as="style" href="/css/quote_api.css?id=20d4b1d267383e725d3b6fac19fed7c7" rel="preload"/>
# <link as="script" href="/js/quoteapi-config.js?id=5f5ad03bdea1a8d4f25028e18091a66b" rel="preload"/>
# <link as="script" href="/js/quoteapi.js?id=97f215deb4d8c9540fd509ab0657a961" rel="preload"/>
# <link href="https://files.marketindex.com.au" rel="preconnect"/>
# <link crossorigin="" href="https://api.marketindex.com.au" rel="preconnect"/>
# <link crossorigin="" href="https://quoteapi.com" rel="preconnect"/>
# <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
# <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link href="/news/feed" rel="alternate" title="RSS Feed for Market Index News" type="application/rss+xml"/>
# <link href="/css/quote_api.css?id=20d4b1d267383e725d3b6fac19fed7c7" rel="stylesheet" type="text/css"/>
# <link href="/css/app.css?id=49cf098fae2e50c34bde0c8906cf40f5" rel="stylesheet" type="text/css"/>
# <link href="/images/favicon.png" rel="icon" type="image/png"/>
# <link href="/images/favicon-96x96.png" rel="shortcut icon" sizes="96x96"/>
# <link href="/images/apple-icon.png" rel="apple-touch-icon"/>
# <link href="/images/android-icon.png" rel="shortcut icon" sizes="196x196"/>
# <meta content="Market Index" name="apple-mobile-web-app-title"/>
# <meta content="Market Index" name="application-name"/>
# <meta content="Market Index" property="og:site_name"/>
# <meta content="https://www.marketindex.com.au/asx-listed-companies" property="og:url"/>
# <meta content="ASX Listed Companies (Full List) - Market Index" property="og:title"/>
# <meta content="Full list of ASX companies ranked by size. Sort alphabetically, by performance or market cap. Link to all company details and price history." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://files.marketindex.com.au/files/og-default-image.png" property="og:image"/>
# <script async="" src="https://static.hotjar.com/c/hotjar-2042371.js?sv=7" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-R504V9JPBH&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-T37QM74"></script><script type="text/javascript">
#     window.routes = {"admin":"\/admin","login":"\/login","logout":"\/logout","register":"\/register"};
#     window.quoteApiKey = "af5f4d73c1a54a33";
#     window.context = {};
#     window.context.apiKey = "";
#     window.context.staticFileUrl = "https://files.marketindex.com.au/";
#     window.context.watchlist = {};
#     window.context.watchlist.symbols = undefined;
#     window.context.market = {
#         xasx: {
#             publicHolidayDate: "2023-06-12",
#             close1430Date: "2023-12-22"
#         }
#     };
#     window.eventId = "01HEBWXNGYF8D8J2GNW779ZD8W";
#     window.eventTS = "1699058996766";
#     window.presenceEnabled = "0";
#
#             window.context.userPermissions = [];
#     </script>
# <script defer="" src="/js/manifest.js?id=b4e8ee4a51ac7521ace11ee205df0da6"></script>
# <script defer="" src="/js/mi-common.js?id=3cb8902e2dddeecfd2232020959bcba3"></script>
# <script defer="" src="/js/vendor.js?id=3e8738535a5ac8b318dd620a4a90d0c8"></script>
# <script>
# window.dataLayer = window.dataLayer || [];
# </script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-T37QM74');</script>
# <style>@media only screen and (min-width:992px){.header-logo{-webkit-animation:goLarge .33s forwards;animation:goLarge .33s forwards}.small-header-anim{-webkit-animation:goSmall .33s forwards;animation:goSmall .33s forwards}@-webkit-keyframes goSmall{0%{top:-80px}to{top:0}}@keyframes goSmall{0%{top:-80px}to{top:0}}@-webkit-keyframes goLarge{0%{width:14rem}to{width:16rem}}@keyframes goLarge{0%{width:14rem}to{width:16rem}}}@media only screen and (max-width:992px){.small-to-full-header-anim{-webkit-animation:goSmallToFull .33s forwards;animation:goSmallToFull .33s forwards}.full-to-small-header-anim{-webkit-animation:goFullToSmall .33s forwards;animation:goFullToSmall .33s forwards}@-webkit-keyframes goSmall{0%{top:-135px}to{top:-45px}}@keyframes goSmall{0%{top:-135px}to{top:-45px}}@-webkit-keyframes goSmallToFull{0%{top:var(--header-anim-end-top)}to{top:var(--header-anim-start-top)}}@keyframes goSmallToFull{0%{top:var(--header-anim-end-top)}to{top:var(--header-anim-start-top)}}@-webkit-keyframes goFullToSmall{0%{top:var(--header-anim-start-top)}to{top:var(--header-anim-end-top)}}@keyframes goFullToSmall{0%{top:var(--header-anim-start-top)}to{top:var(--header-anim-end-top)}}}</style><style>.mobile-nav-border li{border-bottom-width:1px}.mobile-nav-border li:last-child{border-bottom:none}</style><style>td[data-v-119f96b8]{padding-bottom:8px;padding-top:8px}td[data-v-119f96b8]:first-child{padding-left:12px}td[data-v-119f96b8]:last-child{padding-right:0}@media (min-width:992px){td[data-v-119f96b8]:first-child{padding-left:16px}td[data-v-119f96b8]:last-child{padding-right:16px}}input[type=checkbox][data-v-119f96b8],input[type=radio][data-v-119f96b8]{display:none}input[type=checkbox]+label[data-v-119f96b8],input[type=radio]+label[data-v-119f96b8]{cursor:pointer;padding-left:1rem;position:relative}input[type=radio]+label[data-v-119f96b8]:before{border-radius:9999px}input[type=checkbox]+label[data-v-119f96b8]:before,input[type=radio]+label[data-v-119f96b8]:before{--tw-border-opacity:1;--tw-bg-opacity:1;background-color:rgb(247 250 252/var(--tw-bg-opacity));border-color:rgb(178 195 210/var(--tw-border-opacity));border-width:1px;content:"";height:24px;left:-3px;position:absolute;top:-3px;width:24px}input[type=checkbox]+label[data-v-119f96b8]:before{border-radius:.375rem}input[type=radio]:checked+label[data-v-119f96b8]:before{background-image:url(/images/icons/radio-bg.svg)}input[type=checkbox]:checked+label[data-v-119f96b8]:before,input[type=radio]:checked+label[data-v-119f96b8]:before{background-position:50%;background-repeat:no-repeat;background-size:cover;border-style:none}input[type=checkbox]:checked+label[data-v-119f96b8]:before{background-image:url(/images/icons/checkbox-bg.svg)}input[type=checkbox]:is(:checked:disabled)+label[data-v-119f96b8]:before{background-image:url(/images/icons/checkbox-bg-diabled.svg);background-position:50%;background-repeat:no-repeat;background-size:cover;border-style:none}</style><style>.dropdown_items :last-child{border-bottom-left-radius:1rem;border-bottom-right-radius:1rem;border-style:none}</style><style>.set-content[data-v-35004726]:after{content:attr(data-content)}@media (min-width:992px){.set-content[data-v-35004726]:after{content:attr(data-content-lg)}}tbody tr[data-v-35004726]:nth-child(2n){--tw-bg-opacity:1;background-color:rgb(247 250 252/var(--tw-bg-opacity))}</style><style>.vfm--fixed{position:fixed}.vfm--absolute{position:absolute}.vfm--inset{bottom:0;left:0;right:0;top:0}.vfm--overlay{background-color:#00000080;z-index:-1}.vfm--prevent-none{pointer-events:none}.vfm--prevent-auto{pointer-events:auto}.vfm--outline-none:focus{outline:none}.vfm-fade-enter-active,.vfm-fade-leave-active{transition:opacity .3s}.vfm-fade-enter-from,.vfm-fade-leave-to{opacity:0}.vfm-bounce-back{transition-duration:.3s;transition-property:transform}.vfm-slide-down-enter-active,.vfm-slide-down-leave-active,.vfm-slide-up-enter-active,.vfm-slide-up-leave-active{transition:transform .3s ease}.vfm-slide-down-enter-from,.vf ...

# %%
# Import Splinter and BeautifulSoup
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup

# Set up Splinter
browser = Browser('chrome')

# Define the URL of the website you want to scrape
url = "https://www.marketindex.com.au/asx-listed-companies"

# Use Splinter to open the URL
browser.visit(url)

# Get the HTML content from the page
html_content = browser.html

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Find the <div> with class "scroll-overlay"
scroll_overlay_div = soup.find('div', class_='scroll-overlay')

# Check if the <div> is found
if scroll_overlay_div:
    # Extract the rows by splitting the content
    rows = scroll_overlay_div.text.strip().split('\n')
else:
    print("The <div> with class 'scroll-overlay' was not found on the page.")

# Initialize empty lists to store data
rank = []
code = []
company = []
price = []
day_1 = []
week_1 = []
month_1 = []
year_1 = []
sector = []
market_cap = []

# Loop through rows and extract data
for row in rows[1:]:
    fields = row.split('+')
    rank.append(fields[0].strip())
    code.append(fields[1].strip())
    company.append(fields[2].split('$')[0].strip())
    price.append(fields[2].split('$')[1])
    day_1.append(fields[3])
    week_1.append(fields[4])
    month_1.append(fields[5])
    year_1.append(fields[6])
    sector.append(fields[7].split('$')[0].strip())
    market_cap.append(fields[7].split('$')[1])

# Create a DataFrame
data = {
    'Rank': rank,
    'Code': code,
    'Company': company,
    'Price': price,
    '1 Day': day_1,
    '1 Week': week_1,
    '1 Month': month_1,
    '1 Year': year_1,
    'Sector': sector,
    'Mkt Cap': market_cap
}

df = pd.DataFrame(data)

# Display the DataFrame
df.head(10)
# Out:
# Empty DataFrame
# Columns: [Rank, Code, Company, Price, 1 Day, 1 Week, 1 Month, 1 Year, Sector, Mkt Cap]
# Index: []

# %%
# Import Splinter and BeautifulSoup
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup

# Set up Splinter
browser = Browser('chrome')

# Define the URL of the website you want to scrape
url = "https://www.marketindex.com.au/asx-listed-companies"

# Use Splinter to open the URL
browser.visit(url)

# Get the HTML content from the page
html_content = browser.html

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Find the main table element
table = soup.find('table', {'class': 'mi-table mt-6'})

# Check if the table is found
if table:
    # Extract table rows
    rows = table.find_all('tr')
    
    # Initialize empty lists to store data
    rank = []
    code = []
    company = []
    price = []
    day_1 = []
    week_1 = []
    month_1 = []
    year_1 = []
    sector = []
    market_cap = []

    # Loop through rows and extract data
    for row in rows[1:]:  # Start from the second row to skip the header
        columns = row.find_all('td')
        rank.append(columns[0].get_text())
        code.append(columns[2].get_text())
        company.append(columns[3].get_text())
        price.append(columns[4].get_text())
        day_1.append(columns[5].get_text())
        week_1.append(columns[6].get_text())
        month_1.append(columns[7].get_text())
        year_1.append(columns[8].get_text())
        sector.append(columns[9].get_text())
        market_cap.append(columns[10].get_text())

    # Create a DataFrame
    data = {
        'Rank': rank,
        'Code': code,
        'Company': company,
        'Price': price,
        '1 Day': day_1,
        '1 Week': week_1,
        '1 Month': month_1,
        '1 Year': year_1,
        'Sector': sector,
        'Mkt Cap': market_cap
    }

    df = pd.DataFrame(data)

    # Display the DataFrame
    print(df.head(10))
else:
    print("The table with class 'mi-table mt-6' was not found on the page.")
# Out:
#   Rank Code                            Company    Price   1 Day  1 Week  \
# 0    1  BHP                   BHPBHP Group Ltd   $45.61  +0.51%  +1.51%
# 1    2  CBA  CBACommonwealth Bank of Australia   $99.89  +1.48%  +2.98%
# 2    3  CSL                         CSLCSL Ltd  $243.90  +2.44%  +4.08%
# 3    4  NAB     NABNational Australia Bank Ltd   $28.95  +1.33%  +2.66%
# 4    5  ANZ          ANZANZ Group Holdings Ltd   $25.61  +0.95%  +3.31%
# 5    6  WBC     WBCWestpac Banking Corporation  $21.465  +1.39%  +4.35%
# 6    7  FMG      FMGFortescue Metals Group Ltd  $23.265  +0.07%  +4.75%
# 7    8  WDS       WDSWoodside Energy Group Ltd  $34.025  +0.52%  -2.51%
# 8    9  MQG             MQGMacquarie Group Ltd  $161.95  +0.97%  +0.34%
# 9   10  WES                  WESWesfarmers Ltd   $52.31  +1.71%  +3.85%
#
#    1 Month   1 Year                  Sector   Mkt Cap
# 0   +2.27%  +20.09%               Materials  $231.19B
# 1   +0.04%   -4.41%              Financials  $167.37B
# 2   -1.00%  -12.37%             Health Care  $117.82B
# 3   -0.04%   -9.95%              Financials   $90.58B
# 4   +0.47%   -0.27%              Financials   $76.97B
# 5   +1.59%  -10.23%              Financials   $75.32B
# 6  +10.47%  +52.26%               Materials   $71.63B
# 7   -6.14%   -7.39%                  Energy    $64.6B
# 8   -3.52%   -2.70%              Financials   $62.59B
# 9   -0.46%  +16.17%  Consumer Discretionary   $59.32B

# %%
df.head(10)
# Out:
#   Rank Code                            Company    Price   1 Day  1 Week  \
# 0    1  BHP                   BHPBHP Group Ltd   $45.61  +0.51%  +1.51%
# 1    2  CBA  CBACommonwealth Bank of Australia   $99.89  +1.48%  +2.98%
# 2    3  CSL                         CSLCSL Ltd  $243.90  +2.44%  +4.08%
# 3    4  NAB     NABNational Australia Bank Ltd   $28.95  +1.33%  +2.66%
# 4    5  ANZ          ANZANZ Group Holdings Ltd   $25.61  +0.95%  +3.31%
# 5    6  WBC     WBCWestpac Banking Corporation  $21.465  +1.39%  +4.35%
# 6    7  FMG      FMGFortescue Metals Group Ltd  $23.265  +0.07%  +4.75%
# 7    8  WDS       WDSWoodside Energy Group Ltd  $34.025  +0.52%  -2.51%
# 8    9  MQG             MQGMacquarie Group Ltd  $161.95  +0.97%  +0.34%
# 9   10  WES                  WESWesfarmers Ltd   $52.31  +1.71%  +3.85%
#
#    1 Month   1 Year                  Sector   Mkt Cap
# 0   +2.27%  +20.09%               Materials  $231.19B
# 1   +0.04%   -4.41%              Financials  $167.37B
# 2   -1.00%  -12.37%             Health Care  $117.82B
# 3   -0.04%   -9.95%              Financials   $90.58B
# 4   +0.47%   -0.27%              Financials   $76.97B
# 5   +1.59%  -10.23%              Financials   $75.32B
# 6  +10.47%  +52.26%               Materials   $71.63B
# 7   -6.14%   -7.39%                  Energy    $64.6B
# 8   -3.52%   -2.70%              Financials   $62.59B
# 9   -0.46%  +16.17%  Consumer Discretionary   $59.32B

# %%
print(df.dtypes)
print(df.describe())
# Out:
# Rank       object
# Code       object
# Company    object
# Price      object
# 1 Day      object
# 1 Week     object
# 1 Month    object
# 1 Year     object
# Sector     object
# Mkt Cap    object
# dtype: object
#         Rank  Code           Company   Price  1 Day 1 Week 1 Month 1 Year  \
# count   2407  2407              2407    2407   2407   2407    2407   2407
# unique  2407  2407              2407    1048    699   1029    1238   1794
# top        1   BHP  BHPBHP Group Ltd  $0.005  0.00%  0.00%   0.00%  0.00%
# freq       1     1                 1      28    940    445     259     67
#
#            Sector Mkt Cap
# count        2407    2407
# unique         12    2132
# top     Materials  $3.84M
# freq          818       4

# %%
# Check how many unique items are in the "Sector" column
unique_sectors_count = df['Sector'].nunique()
print(f"Number of unique sectors: {unique_sectors_count}")

# List the unique sectors
unique_sectors = df['Sector'].unique()
print("Unique sectors:")
for sector in unique_sectors:
    print(sector)
# Out:
# Number of unique sectors: 12
# Unique sectors:
# Materials
# Financials
# Health Care
# Energy
# Consumer Discretionary
# Communication Services
# Consumer Staples
# Real Estate
# Industrials
# Information Technology
# Utilities
# N/A

# %%
# Remove the "$" and "B" from the "Mkt Cap" column
df['Mkt Cap'] = df['Mkt Cap'].str.replace('$', '')

# Rename the "Mkt Cap" column to "Mkt Cap ($B)"
df.rename(columns={'Mkt Cap': 'Mkt Cap ($)'}, inplace=True)

# %%
df.head()
# Out:
#   Rank Code                            Company    Price   1 Day  1 Week  \
# 0    1  BHP                   BHPBHP Group Ltd   $45.61  +0.51%  +1.51%
# 1    2  CBA  CBACommonwealth Bank of Australia   $99.89  +1.48%  +2.98%
# 2    3  CSL                         CSLCSL Ltd  $243.90  +2.44%  +4.08%
# 3    4  NAB     NABNational Australia Bank Ltd   $28.95  +1.33%  +2.66%
# 4    5  ANZ          ANZANZ Group Holdings Ltd   $25.61  +0.95%  +3.31%
#
#   1 Month   1 Year       Sector Mkt Cap ($)
# 0  +2.27%  +20.09%    Materials     231.19B
# 1  +0.04%   -4.41%   Financials     167.37B
# 2  -1.00%  -12.37%  Health Care     117.82B
# 3  -0.04%   -9.95%   Financials      90.58B
# 4  +0.47%   -0.27%   Financials      76.97B

# %%
# Sort the DataFrame by the "Mkt Cap ($B)" column in descending order
df_sorted = df.sort_values(by='Mkt Cap ($B)', ascending=False)

# Initialize an empty dictionary to store the top 10 entries per sector
top_10_per_sector = {}

# Loop through unique sectors and select the top 10 entries for each sector
unique_sectors = df_sorted['Sector'].unique()
for sector in unique_sectors:
    sector_df = df_sorted[df_sorted['Sector'] == sector]
    top_10_per_sector[sector] = sector_df.head(10)

# Print the top 10 entries per sector based on Mkt Cap ($B)
for sector, top_10_df in top_10_per_sector.items():
    print(f"Top 10 entries for Sector {sector} based on Mkt Cap ($B):")
    print(top_10_df)
    print("\n")
# Out:
# Top 10 entries for Sector Financials based on Mkt Cap ($B):
#       Rank  Code                                            Company   Price  \
# 2383  2384  UTIP  UTIPBetashares Inflation Protected US TRSY Bon...  $24.77
# 299    300   JDO                       JDOJudo Capital Holdings Ltd  $0.893
# 2384  2385  US10      US10Betashares US Treasury Bond 7-10YR CH ETF  $49.30
# 2385  2386  IUSG    IUSGIshares U.S. Treasury Bond (Aud Hedged) ETF  $97.74
# 2386  2387  FUTR  FUTRJanus Henderson GLB Sust Active ETF (Manag...  $27.73
# 924    925  FDEM  FDEMFidelity Global Demographics Fund (Managed...  $25.44
# 930    931  PAXX  PAXXPlatinum Asia Fund (Quoted Managed Hedge F...   $4.10
# 935    936  GLIN  GLINIshares Ftse GBL Infrastructure (Aud Hedge...  $22.96
# 939    940   EP1                         EP1E&P Financial Group Ltd   $0.39
# 940    941  IIND                   IINDBetashares India Quality ETF  $10.70
#
#        1 Day  1 Week  1 Month   1 Year      Sector Mkt Cap ($B)
# 2383  +0.20%  +1.31%   +0.28%   -0.92%  Financials      990.8TH
# 299   +1.42%  +5.00%  -11.19%  -29.72%  Financials      990.05M
# 2384  +0.29%  +2.03%   -0.38%   -0.63%  Financials        986TH
# 2385   0.00%  -0.12%   -1.41%   -1.41%  Financials      977.4TH
# 2386   0.00%   0.00%   -2.74%   +9.52%  Financials     972.57TH
# 924   +1.19%  +1.76%   +0.40%  +12.52%  Financials       97.97M
# 930   +0.74%  +1.24%   -2.15%  +15.17%  Financials       96.68M
# 935   +2.18%  +4.55%   +1.73%   -7.01%  Financials       94.14M
# 939   -3.70%  -6.02%  -11.36%  -23.53%  Financials        92.7M
# 940   +0.66%  -0.37%   -0.65%   -0.19%  Financials       92.49M
#
#
# Top 10 entries for Sector Materials based on Mkt Cap ($B):
#     Rank Code                            Company   Price    1 Day   1 Week  \
# 298  299  SLR       SLRSilver Lake Resources Ltd   $1.06   -0.47%   +8.72%
# 922  923  EUR            EUREuropean Lithium Ltd  $0.071   +1.43%   +7.58%
# 303  304  WGX          WGXWestgold Resources Ltd   $2.06   -2.83%   +4.84%
# 925  926  CNB           CNBCarnaby Resources Ltd   $0.60   +5.26%  -26.38%
# 926  927  COB        COBCobalt Blue Holdings Ltd   $0.26   +1.96%  +10.64%
# 306  307  VSL                VSLVulcan Steel Ltd   $7.33   +0.69%   +1.10%
# 932  933  G6M              G6MGroup 6 Metals Ltd  $0.095  -13.64%   -5.00%
# 933  934  TGM            TGMTheta Gold Mines Ltd  $0.135    0.00%   +8.00%
# 937  938  MNS  MNSMagnis Energy Technologies Ltd  $0.078   +6.85%   +5.41%
# 944  945  ORN              ORNOrion Minerals Ltd  $0.016   -5.88%   -5.88%
#
#      1 Month    1 Year     Sector Mkt Cap ($B)
# 298  +23.98%    -4.07%  Materials      990.83M
# 922   -4.05%   -32.38%  Materials       98.99M
# 303  +19.77%  +184.14%  Materials      975.66M
# 925  -31.03%   -31.82%  Materials       97.71M
# 926   -1.89%   -60.52%  Materials        97.6M
# 306   -2.40%    -9.84%  Materials      963.22M
# 932   +5.56%   -51.90%  Materials       95.33M
# 933   +8.00%   +66.67%  Materials       95.19M
# 937   +5.41%   -78.33%  Materials       93.56M
# 944  -15.79%   -20.00%  Materials       90.99M
#
#
# Top 10 entries for Sector Health Care based on Mkt Cap ($B):
#       Rank Code                       Company   Price   1 Day   1 Week  \
# 918    919  SDI                    SDISDI Ltd   $0.84  +2.44%   +1.82%
# 928    929  VLS     VLSVita Life Sciences Ltd  $1.798   0.00%   +3.90%
# 945    946  RCE  RCERecce Pharmaceuticals Ltd  $0.445  +2.30%   -1.11%
# 1861  1862  BOD            BODBOD Science Ltd  $0.056   0.00%   -6.67%
# 1889  1890  UCM                  UCMUscom Ltd  $0.049   0.00%    0.00%
# 949    950  BIT                BITBiotron Ltd  $0.099  +2.06%  +16.47%
# 317    318  PNV               PNVPolynovo Ltd  $1.265  +1.20%  +11.45%
# 955    956  ALC         ALCAlcidion Group Ltd  $0.069  -1.43%  -34.29%
# 968    969  ALA  ALAArovella Therapeutics Ltd  $0.094  -1.05%   +6.82%
# 988    989  MAP  MAPMicroba Life Sciences Ltd   $0.23   0.00%    0.00%
#
#       1 Month    1 Year       Sector Mkt Cap ($B)
# 918    +5.00%    +1.82%  Health Care       99.85M
# 928    +6.36%   +12.34%  Health Care       96.92M
# 945    -3.26%   -29.77%  Health Care       90.54M
# 1861  -21.13%   -41.05%  Health Care        9.93M
# 1889   -2.00%    -2.00%  Health Care        9.34M
# 949   +12.50%  +175.00%  Health Care       89.31M
# 317    -4.89%   -36.59%  Health Care      873.14M
# 955   -40.00%   -55.48%  Health Care       87.66M
# 968   +42.42%  +268.63%  Health Care       85.19M
# 988   -32.31%   +31.73%  Health Care       81.21M
#
#
# Top 10 entries for Sector Consumer Staples based on Mkt Cap ($B):
#       Rank Code                                 Company   Price   1 Day  \
# 919    920  AVG               AVGAustralian Vintage Ltd  $0.395  -1.25%
# 304    305  ELD                           ELDElders Ltd   $6.21  +3.50%
# 52      53  EDV                  EDVEndeavour Group Ltd   $5.04  +2.23%
# 322    323  BGA                      BGABega Cheese Ltd   $2.80   0.00%
# 1921  1922  AN1                        AN1Anagenics Ltd  $0.023   0.00%
# 1928  1929  BEE                             BEEBroo Ltd  $0.009   0.00%
# 1945  1946  PFT              PFTPure Foods Tasmania Ltd  $0.075  -5.06%
# 63      64  TWE            TWETreasury Wine Estates Ltd  $11.22  -7.27%
# 343    344  AAC  AACAustralian Agricultural Company Ltd  $1.253  -1.38%
# 360    361  RIC               RICRidley Corporation Ltd   $2.24  +0.45%
#
#       1 Week  1 Month   1 Year            Sector Mkt Cap ($B)
# 919   -2.47%   +6.76%  -39.23%  Consumer Staples       99.79M
# 304   +5.43%   +8.57%  -52.67%  Consumer Staples      971.72M
# 52    +3.92%   -3.63%  -28.21%  Consumer Staples         9.03
# 322   -2.78%  +12.45%  -14.89%  Consumer Staples      852.65M
# 1921  -4.17%    0.00%  -29.64%  Consumer Staples        8.71M
# 1928   0.00%    0.00%    0.00%  Consumer Staples        8.57M
# 1945  -5.06%  -21.88%  -54.55%  Consumer Staples        8.25M
# 63    -6.27%   -7.27%  -12.00%  Consumer Staples          8.1
# 343   +7.05%   -5.11%  -30.61%  Consumer Staples      754.97M
# 360   +4.19%   -2.61%   +4.19%  Consumer Staples      707.47M
#
#
# Top 10 entries for Sector Information Technology based on Mkt Cap ($B):
#       Rank Code                     Company   Price    1 Day    1 Week  \
# 920    921  RWL        RWLRubicon Water Ltd   $0.58    0.00%    +0.87%
# 302    303  IRE                IREIress Ltd  $5.245   +1.65%    +3.66%
# 927    928  ACE            ACEAcusensus Ltd   $0.77   -2.53%    +1.32%
# 938    939  BLG             BLGBluglass Ltd  $0.061   -4.69%    +8.93%
# 946    947  WCG           WCGWebcentral Ltd  $0.275   -1.79%  +150.00%
# 1874  1875  ICE              ICEIcetana Ltd  $0.038  +11.77%   +11.77%
# 1877  1878  ADS               ADSAdslot Ltd  $0.003    0.00%   -25.00%
# 1900  1901  NVU              NVUNanoveu Ltd  $0.023    0.00%     0.00%
# 1901  1902  LNU  LNULinius Technologies Ltd  $0.002    0.00%     0.00%
# 1902  1903  SPA            SPASpacetalk Ltd   $0.02    0.00%    -9.09%
#
#        1 Month    1 Year                  Sector Mkt Cap ($B)
# 920     -2.52%   -38.62%  Information Technology       99.69M
# 302     -9.10%   -46.10%  Information Technology      979.71M
# 927     -8.33%    -3.75%  Information Technology       97.14M
# 938    +52.50%  +110.45%  Information Technology       93.21M
# 946   +103.70%   +52.78%  Information Technology       90.51M
# 1874   +15.15%   -30.91%  Information Technology        9.71M
# 1877   -40.00%   -75.00%  Information Technology        9.67M
# 1900     0.00%   +91.67%  Information Technology        9.08M
# 1901   -20.00%   -42.86%  Information Technology        9.04M
# 1902    -4.76%   -42.99%  Information Technology        9.01M
#
#
# Top 10 entries for Sector Energy based on Mkt Cap ($B):
#       Rank Code                     Company   Price    1 Day   1 Week  \
# 921    922  BYE         BYEByron Energy Ltd  $0.092   -3.16%   +8.24%
# 301    302  STX        STXStrike Energy Ltd  $0.388   +0.65%   -5.49%
# 1867  1868  NAE  NAENew Age Exploration Ltd  $0.006    0.00%    0.00%
# 1873  1874  CXU      CXUCauldron Energy Ltd   $0.01  +11.11%  +11.11%
# 2389  2390  LAM   LAMLaramide Resources Ltd   $0.68    0.00%   -5.56%
# 958    959  ACB         ACBA-Cap Energy Ltd  $0.068    0.00%    0.00%
# 984    985  OEL          OELOtto Energy Ltd  $0.017    0.00%  -10.53%
# 989    990  BRU          BRUBuru Energy Ltd  $0.135   +3.85%  +28.57%
# 1920  1921  T88     T88Taiton Resources Ltd   $0.17    0.00%   -5.56%
# 1949  1950  LIO          LIOLion Energy Ltd  $0.019    0.00%   -9.52%
#
#       1 Month   1 Year  Sector Mkt Cap ($B)
# 921    +9.52%  -31.85%  Energy       99.49M
# 301    -4.32%  +61.46%  Energy      983.98M
# 1867   -8.33%  -31.25%  Energy        9.87M
# 1873  -15.46%   -4.80%  Energy        9.74M
# 2389  -13.92%  -13.38%  Energy     882.06TH
# 958    -5.56%  -10.53%  Energy        86.5M
# 984   -15.00%  +21.43%  Energy       81.52M
# 989   +42.11%  +55.17%  Energy       80.47M
# 1920   -8.11%  -15.00%  Energy        8.76M
# 1949   -9.52%  -47.22%  Energy        8.15M
#
#
# Top 10 entries for Sector Consumer Discretionary based on Mkt Cap ($B):
#       Rank Code                            Company    Price    1 Day   1 Week  \
# 300    301  BGP   BGPBriscoe Group Australasia Ltd    $4.42    0.00%    0.00%
# 929    930  ABY          ABYAdore Beauty Group Ltd    $1.03   -1.91%   +9.57%
# 936    937  TWD                    TWDTamawood Ltd    $2.65   +4.33%  +10.42%
# 311    312  NCK                  NCKNick Scali Ltd  $11.295   +2.22%   +5.96%
# 1875  1876  OLI          OLIOliver's Real Food Ltd   $0.022   +4.76%   +4.76%
# 318    319  JIN           JINJumbo Interactive Ltd   $13.85   -1.28%   -0.29%
# 956    957  BET  BETBetmakers Technology Group Ltd   $0.092  +12.20%  +10.84%
# 976    977  JYC           JYCJoyce Corporation Ltd    $2.91    0.00%   +0.35%
# 985    986  SHM             SHMShriro Holdings Ltd   $0.845    0.00%   -0.59%
# 335    336  GEM                GEMG8 Education Ltd    $0.97   +1.04%    0.00%
#
#       1 Month   1 Year                  Sector Mkt Cap ($B)
# 300    +0.23%  -12.99%  Consumer Discretionary      984.62M
# 929   +38.26%  -36.81%  Consumer Discretionary       96.72M
# 936   +23.26%  +10.42%  Consumer Discretionary       93.91M
# 311    +2.03%  +13.98%  Consumer Discretionary       914.9M
# 1875  -12.00%  -62.71%  Consumer Discretionary         9.7M
# 318    -7.67%   +0.51%  Consumer Discretionary      872.43M
# 956     0.00%  -65.28%  Consumer Discretionary       87.24M
# 976    -4.59%  -16.86%  Consumer Discretionary       82.96M
# 985     0.00%   +8.33%  Consumer Discretionary       81.47M
# 335    -8.06%   -4.43%  Consumer Discretionary      785.22M
#
#
# Top 10 entries for Sector Industrials based on Mkt Cap ($B):
#       Rank Code                           Company   Price   1 Day  1 Week  \
# 923    924  REX  REXRegional Express Holdings Ltd   $0.88  -2.22%  -1.12%
# 934    935  LBL                  LBLLaserbond Ltd   $0.86  -1.15%  -1.15%
# 943    944  FBR                        FBRFBR Ltd  $0.023   0.00%  -4.17%
# 947    948  KOV                    KOVKorvest Ltd   $7.75   0.00%  -0.64%
# 1866  1867  BPP       BPPBabylon Pump & Power Ltd  $0.004   0.00%   0.00%
# 1869  1870  OLH         OLHOldfields Holdings Ltd  $0.049   0.00%  -2.00%
# 1886  1887  FOS                FOSFOS Capital Ltd  $0.175  +2.94%  +9.38%
# 1896  1897  SSH                  SSHSSH Group Ltd   $0.14   0.00%   0.00%
# 314    315  SGF             SGFSG Fleet Group Ltd   $2.61  -0.76%  +2.76%
# 964    965  HIT     HITHitech Group Australia Ltd   $2.04  +2.00%  -3.32%
#
#       1 Month   1 Year       Sector Mkt Cap ($B)
# 923   -12.00%  -37.14%  Industrials       98.19M
# 934    +0.59%    0.00%  Industrials       94.82M
# 943   -16.36%  -51.06%  Industrials       91.42M
# 947    -6.17%   +3.47%  Industrials       90.44M
# 1866    0.00%  -33.33%  Industrials        9.88M
# 1869   -2.00%  -35.53%  Industrials        9.79M
# 1886    0.00%  -12.50%  Industrials        9.42M
# 1896    0.00%  -20.00%  Industrials        9.23M
# 314    +7.85%  +27.94%  Industrials      892.58M
# 964    +4.62%   +2.00%  Industrials       86.09M
#
#
# Top 10 entries for Sector N/A based on Mkt Cap ($B):
#       Rank    Code                                           Company    Price  \
# 305    306   AN3PH  AN3PHAustralia and New Zealand Banking Group Ltd  $103.75
# 308    309   MQGPD                          MQGPDMacquarie Group Ltd  $105.39
# 2388  2389    LBTR                           LBTRLBT Innovations Ltd   $0.001
# 1881  1882   GFLGA                      GFLGAGlobal Masters Fund Ltd    $2.98
# 2402  2403    MGTR                           MGTRMagnetite Mines Ltd   $0.004
# 2403  2404   EMUCA                                       EMUCAEMU NL   $0.002
# 1914  1915  YTMORG                         YTMORGEquity Trustees Ltd   $95.28
# 1930  1931  YTMQF4                         YTMQF4Equity Trustees Ltd   $87.72
# 1942  1943  YTMDO2                         YTMDO2Equity Trustees Ltd   $96.68
# 1947  1948  YTMMQ1                         YTMMQ1Equity Trustees Ltd   $97.16
#
#         1 Day   1 Week  1 Month    1 Year Sector Mkt Cap ($B)
# 305    +0.12%   +0.87%    0.00%    -1.18%    N/A      965.99M
# 308    -0.10%   -0.05%   -0.48%    +0.63%    N/A       954.3M
# 2388    0.00%    0.00%    0.00%     0.00%    N/A        900TH
# 1881    0.00%    0.00%    0.00%    -3.87%    N/A        9.61M
# 2402  -50.00%  +33.33%  +33.33%   +33.33%    N/A      83.74TH
# 2403    0.00%    0.00%    0.00%  +100.00%    N/A      80.97TH
# 1914    0.00%    0.00%    0.00%   +11.45%    N/A        8.84M
# 1930    0.00%    0.00%    0.00%    +7.24%    N/A        8.54M
# 1942    0.00%    0.00%    0.00%    +1.17%    N/A        8.32M
# 1947    0.00%    0.00%    0.00%    -2.84%    N/A        8.22M
#
#
# Top 10 entries for Sector Real Estate based on Mkt Cap ($B):
#     Rank Code                                     Company   Price   1 Day  \
# 307  308  CMW                  CMWCromwell Property Group  $0.365  +4.29%
# 310  311  CQE  CQECharter Hall Social Infrastructure REIT   $2.53  +2.02%
# 312  313  ABG                             ABGAbacus Group   $1.02  +2.51%
# 331  332  HCW    HCWHealthco Healthcare and Wellness REIT   $1.42  +1.43%
# 332  333  DXI                     DXIDexus Industria REIT   $2.54  +2.01%
# 54    55  SGP                                SGPStockland   $3.74  +2.19%
# 61    62  VCX                         VCXVicinity Centres   $1.80  +1.70%
# 997  998  TOT                         TOT360 Capital REIT   $0.54  +0.94%
# 353  354  WTN                          WTNWinton Land Ltd   $2.43   0.00%
# 356  357  COF                     COFCenturia Office REIT   $1.20  +4.35%
#
#      1 Week 1 Month   1 Year       Sector Mkt Cap ($B)
# 307  +5.80%  -3.95%  -47.48%  Real Estate      955.89M
# 310  +2.43%  +0.40%  -25.37%  Real Estate      937.56M
# 312  +0.49%  -2.86%  -62.64%  Real Estate      911.53M
# 331  +0.35%  -2.07%   +1.91%  Real Estate       806.9M
# 332  +1.60%  -2.31%   -4.15%  Real Estate      805.87M
# 54   +5.06%  -4.10%   +8.09%  Real Estate         8.93
# 61   +4.96%  +5.26%   -5.51%  Real Estate         8.19
# 997  +3.85%  -8.48%  -32.08%  Real Estate          78M
# 353  +0.83%  +0.83%   -6.54%  Real Estate      720.77M
# 356  +9.59%  +4.35%  -20.00%  Real Estate       716.8M
#
#
# Top 10 entries for Sector Communication Services based on Mkt Cap ($B):
#       Rank Code                      Company   Price   1 Day   1 Week  \
# 931    932  BBL      BBLBrisbane Broncos Ltd  $0.975  +1.04%   -1.52%
# 309    310  TUA                  TUATuas Ltd   $2.03  -0.98%   -0.98%
# 50      51  TPG           TPGTPG Telecom Ltd   $5.31  +1.14%   +3.51%
# 1890  1891  SW1  SW1Swift Networks Group Ltd  $0.015   0.00%    0.00%
# 1892  1893  RNT           RNTRent.com.Au Ltd  $0.018   0.00%    0.00%
# 321    322  ABB      ABBAussie Broadband Ltd   $3.61  -7.91%   -8.38%
# 971    972  ART             ARTAirtasker Ltd  $0.188  -1.32%   -6.25%
# 1913  1914  INP           INPIncentiapay Ltd  $0.007   0.00%    0.00%
# 1926  1927  MXO                 MXOMotio Ltd  $0.032   0.00%  +23.08%
# 60      61  SPK     SPKSpark New Zealand Ltd  $4.615  -0.32%   +2.33%
#
#       1 Month   1 Year                  Sector Mkt Cap ($B)
# 931    -1.52%   -7.14%  Communication Services       95.59M
# 309    -7.31%  +50.37%  Communication Services      943.87M
# 50     -2.93%  +11.32%  Communication Services         9.87
# 1890  -21.05%  +15.39%  Communication Services        9.31M
# 1892  -10.00%  -51.35%  Communication Services        9.27M
# 321   -11.52%  +43.25%  Communication Services      863.55M
# 971    -6.25%  -45.65%  Communication Services        84.7M
# 1913  -12.50%  -22.22%  Communication Services        8.86M
# 1926  +18.52%   -8.57%  Communication Services        8.58M
# 60     +3.71%   -0.54%  Communication Services         8.45
#
#
# Top 10 entries for Sector Utilities based on Mkt Cap ($B):
#       Rank Code                                   Company   Price   1 Day  \
# 962    963  EWC           EWCEnergy World Corporation Ltd  $0.028  +7.69%
# 969    970  TPC                   TPCTPC Consolidated Ltd   $7.51  +0.67%
# 1938  1939  LPE  LPELocality Planning Energy Holdings Ltd  $0.047   0.00%
# 1970  1971  KPO                       KPOKalina Power Ltd  $0.005   0.00%
# 68      69  MCY                         MCYMercury NZ Ltd   $5.40  -1.46%
# 72      73  AGL                         AGLAGL Energy Ltd  $10.59  +0.67%
# 1995  1996  PO3                           PO3Purifloh Ltd   $0.22   0.00%
# 2014  2015  DEL               DELDelorean Corporation Ltd  $0.031  +3.33%
# 87      88  MEZ                    MEZMeridian Energy Ltd   $4.60  +2.91%
# 1343  1344  DEM                             DEMDe.Mem Ltd   $0.13   0.00%
#
#        1 Week  1 Month    1 Year     Sector Mkt Cap ($B)
# 962    -3.45%  -20.00%   -34.88%  Utilities       86.21M
# 969   +20.16%  +40.11%  +154.58%  Utilities       85.18M
# 1938   -9.62%   +4.44%   -12.96%  Utilities        8.37M
# 1970  -16.67%  -37.50%   -76.19%  Utilities        7.58M
# 68     -1.82%   -6.74%    +5.47%  Utilities         7.51
# 72     -1.49%   -0.94%   +49.58%  Utilities         7.12
# 1995    0.00%    0.00%   -26.67%  Utilities        7.08M
# 2014   -8.82%  +34.78%   -58.67%  Utilities        6.69M
# 87     +1.77%   -2.34%    +3.84%  Utilities         5.83
# 1343   +4.00%  -10.35%    +8.33%  Utilities       31.89M

# %%
#### Export to csv file

# %%
# Export the DataFrame to a CSV file
df.to_csv('Resources/ASX_Basic_Info.csv', index=False)
