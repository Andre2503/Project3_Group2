# %%
# Dependencies
import pandas as pd
from splinter import Browser
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# %%
# Use the read_csv function to read the CSV file
df = pd.read_csv("Resources/ASX_Top10_Industry.csv")

df.head(10)
# Out:
#   ticker                     company_name               industry_gp  \
# 0    ARB         ARB CORPORATION LIMITED.  Automobiles & Components
# 1    GUD          G.U.D. HOLDINGS LIMITED  Automobiles & Components
# 2    PWH             PWR HOLDINGS LIMITED  Automobiles & Components
# 3    SFC     SCHAFFER CORPORATION LIMITED  Automobiles & Components
# 4    AHL           ADRAD HOLDINGS LIMITED  Automobiles & Components
# 5    VMT                    VMOTO LIMITED  Automobiles & Components
# 6    RPM     RPM AUTOMOTIVE GROUP LIMITED  Automobiles & Components
# 7    ABV  ADVANCED BRAKING TECHNOLOGY LTD  Automobiles & Components
# 8    DDT       DATADOT TECHNOLOGY LIMITED  Automobiles & Components
# 9    SIX                 SPRINTEX LIMITED  Automobiles & Components
#
#      market_cap
# 0  2.455925e+09
# 1  1.534343e+09
# 2  1.000822e+09
# 3  2.272901e+08
# 4  7.275023e+07
# 5  4.353604e+07
# 6  1.573357e+07
# 7  1.555814e+07
# 8  4.843811e+06
# 9  4.745972e+06

# %%
# Extract the "Code" column as a list
tickers = df['ticker'].tolist()

# %%
print(tickers)
# Out:
# ['ARB', 'GUD', 'PWH', 'SFC', 'AHL', 'VMT', 'RPM', 'ABV', 'DDT', 'SIX', 'CBA', 'NAB', 'ANZ', 'WBC', 'BEN', 'VUK', 'BOQ', 'BFL', 'HGH', 'JDO', 'REH', 'SVW', 'WOR', 'IFT', 'FBU', 'RWC', 'VNT', 'JLG', 'MND', 'RDX', 'SLB', 'TRE', 'OXT', 'S3N', 'HRE', 'KLI', 'DY6', 'BXB', 'CPU', 'ALQ', 'CWY', 'DOW', 'APM', 'IPH', 'MAD', 'MMS', 'SIQ', 'WES', 'JBH', 'HVN', 'PMV', 'APE', 'SUL', 'LOV', 'BAP', 'AX1', 'BGP', 'BRG', 'AKP', 'FWD', 'WAT', 'AVJ', 'GLB', 'TWD', 'SHM', 'SIO', 'GAP', 'ALL', 'LNW', 'TLC', 'IEL', 'DMP', 'FLT', 'CTD', 'WEB', 'TAH', 'IVC', 'WOW', 'COL', 'EDV', 'MTS', 'GNC', 'MMM', 'WDS', 'STO', 'ALD', 'YAL', 'WHC', 'NXG', 'NHC', 'VEA', 'BPT', 'PDN', 'GMG', 'SCG', 'URW', 'SGP', 'VCX', 'MGR', 'GPT', 'DXS', 'CHC', 'NSR', 'MQG', 'SQ2', 'SOL', 'ASX', 'JHG', 'CGF', 'GQG', 'NWL', 'AMP', 'HUB', 'TWE', 'A2M', 'CGC', 'ING', 'ELD', 'BGA', 'AAC', 'RIC', 'CBO', 'SHV', 'RMD', 'COH', 'SHL', 'FPH', 'RHC', 'PME', 'EBO', 'ANN', 'SNZ', 'NAN', 'PTL', 'MCP', 'BIO', 'BXN', 'S66', 'HPC', 'EXL', 'SKN', 'CCO', 'HCT', 'QBE', 'SUN', 'IAG', 'MPL', 'SDF', 'NHF', 'AUB', 'PSI', 'CVW', 'GDG', 'BHP', 'FMG', 'NEM', 'RIO', 'AMC', 'JHX', 'S32', 'NST', 'MIN', 'PLS', 'NWS', 'NWSLV', 'REA', 'CAR', 'SEK', 'NEC', 'DHG', 'EVT', 'OML', 'SWM', 'AFI', 'ARG', 'MGF', 'MXT', 'WLE', 'LSF', 'WAM', 'MFF', 'BKI', 'AUI', 'CSL', 'TLX', 'NEU', 'CUV', 'AVH', 'IMM', 'AFP', 'MSB', 'MYX', 'IMU', 'LLC', 'PXA', 'LIC', 'UOS', 'WTN', 'QAL', 'PPC', 'CWP', 'SRV', 'FRI', 'WBT', '4DS', 'AXE', 'BLG', 'RVS', 'PVS', 'WTC', 'XRO', 'NXT', 'ALU', 'TNE', 'MP1', '360', 'MAQ', 'SDR', 'DTL', 'DDR', 'CDA', 'AD8', 'NVX', 'SPZ', 'ERD', 'RWL', 'DTZ', 'IKE', 'SMN', 'TLS', 'TPG', 'SPK', 'CNU', 'TUA', 'ABB', 'HTA', 'SLC', 'SWP', 'FSG', 'TCL', 'AIA', 'QAN', 'ALX', 'AZJ', 'QUB', 'AIZ', 'KLS', 'DBI', 'FRW', 'ORG', 'MEZ', 'APA', 'AGL', 'MCY', 'CEN', 'GNE', 'D2O', 'GNX', 'LGI']

# %%
# Set up Splinter
browser = Browser('chrome')

# Define the URL of the website you want to scrape for the given ticker
url = f"https://www.marketindex.com.au/asx/slb"

# Use Splinter to open the URL
browser.visit(url)

# Get the HTML content from the page
html_content = browser.html

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

print(soup.find('h2'))
soup.find('h2').text
# Out:
# <h2 class="text-center text-md lg:text-3xl pl-1 xl:px-16 pt-6 lg:pt-2 border-none">What is live streaming pricing?</h2>
# 'What is live streaming pricing?'

# %%
print(soup.find('h3'))
soup.find('h2').text
# Out:
# <h3 class="hidden xl:block font-bold text-md">Key Information</h3>
# 'What is live streaming pricing?'

# %%
share_price = soup.find_all('div', class_="sm:w-1/2 lg:w-1/3 sm:pr-4 mb-6 lg:mb-0")
print(share_price)
# Out:
# [<div class="sm:w-1/2 lg:w-1/3 sm:pr-4 mb-6 lg:mb-0">
# <h3 class="h3">Share Price Activity (ASX)</h3>
# <table class="mi-table">
# <tbody><tr>
# <td>Last (Price)</td>
# <td class="text-right">
# <span class="quoteapi-number quoteapi-price" data-quoteapi="price">$0.285</span>
# </td>
# </tr>
# <tr>
# <td>Change</td>
# <td class="text-right pos" data-quoteapi="changeSignCSS">
# <span class="quoteapi-number quoteapi-price quoteapi-change" data-quoteapi="change showNegativeSign=false">0.025</span>
# (<span class="quoteapi-number quoteapi-pct-change" data-quoteapi="pctChange showNegativeSign=true">9.62%</span>)
# </td>
# </tr>
# <tr>
# <td>Bid / Ask</td>
# <td class="text-right">
# <span class="quoteapi-number quoteapi-price" data-quoteapi="bid">$0.27</span>
# <span>-</span>
# <span class="quoteapi-number quoteapi-price" data-quoteapi="ask">$0.285</span>
# </td>
# </tr>
# <tr>
# <td>Volume</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-volume" data-quoteapi="volume scale=false">110,064</span></td>
# </tr>
# <tr>
# <td>Volume (4w avg)</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-volume" data-quoteapi="monthAverageVolume scale=false">191,029</span></td>
# </tr>
# <tr>
# <td>Turnover</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-value" data-quoteapi="value scale=false">$30,873</span></td>
# </tr>
# <tr>
# <td>Open</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-price" data-quoteapi="open">$0.265</span></td>
# </tr>
# <tr>
# <td>Day Range</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-price" data-quoteapi="low">$0.265</span> - <span class="quoteapi-number quoteapi-price" data-quoteapi="high">$0.29</span></td>
# </tr>
# <tr>
# <td>VWAP</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-price" data-quoteapi="vwap">$0.2805</span></td>
# </tr>
# <tr>
# <td>Prev Close</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-price" data-quoteapi="prevClose">$0.26</span></td>
# </tr>
# <tr>
# <td>Last Trade</td>
# <td class="text-right"><span data-quoteapi="dateTime format='h:mma DD/MM (z)'">6:58pm 03/11 (AEDT)</span></td>
# </tr>
# </tbody></table>
# </div>]

# %%
performance = soup.find_all('div', class_="sm:w-1/2 lg:w-1/3 sm:pl-4 lg:px-4 mb-6 lg:mb-0")
print(performance)
# Out:
# [<div class="sm:w-1/2 lg:w-1/3 sm:pl-4 lg:px-4 mb-6 lg:mb-0">
# <h3 class="h3">Performance</h3>
# <table class="mi-table">
# <tbody><tr>
# <td>1 Week</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-pct-change neg" data-quoteapi="weekPctChange (fullySigned); weekChangeSignCSS">-1.72%</span></td>
# </tr>
# <tr>
# <td>1 Month</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-pct-change neg" data-quoteapi="monthPctChange (fullySigned); monthChangeSignCSS">-5.00%</span></td>
# </tr>
# <tr>
# <td>2023 YTD</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-pct-change pos" data-quoteapi="ytdPctChange (fullySigned); ytdChangeSignCSS">+83.87%</span></td>
# </tr>
# <tr>
# <td>1 Year</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-pct-change pos" data-quoteapi="yearPctChange (fullySigned); yearChangeSignCSS">+54.05%</span></td>
# </tr>
# <tr>
# <td>vs Sector (1yr)</td>
# <td class="text-right">
# -
# </td>
# </tr>
# <tr>
# <td>vs ASX 200 (1yr)</td>
# <td class="text-right">
# <span class="text-teal-dark">
# +52.30%
# </span>
# </td>
# </tr>
# </tbody></table>
# <div class="mt-6">
# <h3 class="h3">Size</h3>
# <div id="company-overview-size">
# <table class="mi-table">
# <tbody><tr>
# <td>
# <div class="relative">
# <span class="inline-block mr-1">
# Market Cap
# </span>
# <span class="absolute -mt-1 text-normal">
# <a class="xmodal-trigger" data-target="market-cap-explain" href="#" title="Excludes mandatory escrowed shares and foreign shares">
# <img alt="Question Mark Icon" src="https://www.marketindex.com.au/images/icons/question-mark-light.svg"/>
# </a>
# </span>
# </div>
# <div class="xmodal" id="market-cap-explain" name="market-cap-explain">
# <div class="body-content text-center">
# Excludes mandatory escrowed shares and foreign shares.
# </div>
# </div>
# </td>
# <td class="text-right"><span class="quoteapi-number quoteapi-value" data-quoteapi="marketCap scale=false">$14,793,759</span></td>
# </tr>
# <tr>
# <td>ASX Rank</td>
# <td class="text-right">1,687 of 2,408</td>
# </tr>
# <tr>
# <td>Sector Rank</td>
# <td class="text-right">581 of 978</td>
# </tr>
# </tbody></table>
# </div>
# </div>
# </div>]

# %%
size = soup.find_all('div', class_="mt-6")
print(size)
# Out:
# [<div class="hidden lg:flex justify-center mt-6 xl:mt-0 mb-8 pt-8"><img alt="" src="/images/markets/cboe-popup-logo.png" style="max-width: 300px;"/></div>, <div class="mt-6">
# <h3 class="h3">Size</h3>
# <div id="company-overview-size">
# <table class="mi-table">
# <tbody><tr>
# <td>
# <div class="relative">
# <span class="inline-block mr-1">
# Market Cap
# </span>
# <span class="absolute -mt-1 text-normal">
# <a class="xmodal-trigger" data-target="market-cap-explain" href="#" title="Excludes mandatory escrowed shares and foreign shares">
# <img alt="Question Mark Icon" src="https://www.marketindex.com.au/images/icons/question-mark-light.svg"/>
# </a>
# </span>
# </div>
# <div class="xmodal" id="market-cap-explain" name="market-cap-explain">
# <div class="body-content text-center">
# Excludes mandatory escrowed shares and foreign shares.
# </div>
# </div>
# </td>
# <td class="text-right"><span class="quoteapi-number quoteapi-value" data-quoteapi="marketCap scale=false">$14,793,759</span></td>
# </tr>
# <tr>
# <td>ASX Rank</td>
# <td class="text-right">1,687 of 2,408</td>
# </tr>
# <tr>
# <td>Sector Rank</td>
# <td class="text-right">581 of 978</td>
# </tr>
# </tbody></table>
# </div>
# </div>, <div class="sm:w-1/2 lg:w-full sm:pl-4 lg:p-0 mt-6 sm:mt-0 lg:mt-6">
# <h3 class="h3">Broker Consensus</h3>
# <p class="text-sm leading-6">
# SLB is not covered by a major broker, or data from most recent compilation was omitted due
# to not meeting QA guidelines.
# </p>
# </div>, <div class="text-center mt-6 pb-6"><svg class="inline-block" fill="none" height="54" viewbox="0 0 54 54" width="54" xmlns="http://www.w3.org/2000/svg"><circle cx="27" cy="27" fill="#2877E2" opacity="0.15" r="27"></circle><path clip-rule="evenodd" d="M22.7148 32.2096C22.7148 32.0201 22.7901 31.8385 22.9241 31.7045C23.058 31.5706 23.2397 31.4953 23.4291 31.4953H36.2861C36.4755 31.4953 36.6572 31.5706 36.7912 31.7045C36.9251 31.8385 37.0004 32.0201 37.0004 32.2096C37.0004 32.399 36.9251 32.5807 36.7912 32.7147C36.6572 32.8486 36.4755 32.9239 36.2861 32.9239H23.4291C23.2397 32.9239 23.058 32.8486 22.9241 32.7147C22.7901 32.5807 22.7148 32.399 22.7148 32.2096ZM22.7148 26.4954C22.7148 26.3059 22.7901 26.1243 22.9241 25.9903C23.058 25.8564 23.2397 25.7811 23.4291 25.7811H36.2861C36.4755 25.7811 36.6572 25.8564 36.7912 25.9903C36.9251 26.1243 37.0004 26.3059 37.0004 26.4954C37.0004 26.6848 36.9251 26.8665 36.7912 27.0004C36.6572 27.1344 36.4755 27.2097 36.2861 27.2097H23.4291C23.2397 27.2097 23.058 27.1344 22.9241 27.0004C22.7901 26.8665 22.7148 26.6848 22.7148 26.4954ZM22.7148 20.7812C22.7148 20.5917 22.7901 20.4101 22.9241 20.2761C23.058 20.1421 23.2397 20.0669 23.4291 20.0669H36.2861C36.4755 20.0669 36.6572 20.1421 36.7912 20.2761C36.9251 20.4101 37.0004 20.5917 37.0004 20.7812C37.0004 20.9706 36.9251 21.1523 36.7912 21.2862C36.6572 21.4202 36.4755 21.4954 36.2861 21.4954H23.4291C23.2397 21.4954 23.058 21.4202 22.9241 21.2862C22.7901 21.1523 22.7148 20.9706 22.7148 20.7812Z" fill="#2877E2" fill-rule="evenodd"></path><path d="M18.7744 18.9156C18.7987 18.8368 18.8476 18.7679 18.914 18.7189C18.9803 18.67 19.0606 18.6436 19.143 18.6436C19.2254 18.6436 19.3057 18.67 19.372 18.7189C19.4384 18.7679 19.4873 18.8368 19.5116 18.9156L19.743 19.6727C19.793 19.837 19.943 19.9498 20.1115 19.9498H20.8987C21.2687 19.9498 21.4272 20.4255 21.133 20.6541L20.4644 21.1727C20.4012 21.2221 20.3546 21.2895 20.3306 21.3661C20.3066 21.4426 20.3064 21.5246 20.3301 21.6012L20.5773 22.4141C20.6887 22.7798 20.273 23.0741 19.973 22.8426L19.3773 22.3798C19.3103 22.3277 19.2279 22.2994 19.143 22.2994C19.0581 22.2994 18.9757 22.3277 18.9087 22.3798L18.313 22.8412C18.013 23.0741 17.5987 22.7798 17.7087 22.4141L17.9559 21.5998C17.9792 21.5234 17.9789 21.4417 17.9549 21.3654C17.931 21.2892 17.8845 21.222 17.8216 21.1727L17.153 20.6541C16.8587 20.4255 17.0173 19.9498 17.3873 19.9498H18.173C18.2563 19.9496 18.3373 19.9225 18.4039 19.8725C18.4706 19.8226 18.5193 19.7525 18.543 19.6727L18.7744 18.9156ZM18.7744 24.6298C18.7987 24.551 18.8476 24.4821 18.914 24.4331C18.9803 24.3842 19.0606 24.3578 19.143 24.3578C19.2254 24.3578 19.3057 24.3842 19.372 24.4331C19.4384 24.4821 19.4873 24.551 19.5116 24.6298L19.743 25.3869C19.793 25.5512 19.943 25.664 20.1115 25.664H20.8987C21.2687 25.664 21.4272 26.1397 21.133 26.3683L20.4644 26.8869C20.4012 26.9363 20.3546 27.0037 20.3306 27.0803C20.3066 27.1568 20.3064 27.2388 20.3301 27.3154L20.5773 28.1283C20.6887 28.4926 20.273 28.7883 19.973 28.5568L19.3773 28.094C19.3103 28.0419 19.2279 28.0136 19.143 28.0136C19.0581 28.0136 18.9757 28.0419 18.9087 28.094L18.313 28.5554C18.013 28.7883 17.5987 28.494 17.7087 28.1283L17.9559 27.314C17.9792 27.2376 17.9789 27.1559 17.9549 27.0796C17.931 27.0034 17.8845 26.9362 17.8216 26.8869L17.153 26.3683C16.8587 26.1397 17.0173 25.664 17.3873 25.664H18.173C18.2563 25.6638 18.3373 25.6367 18.4039 25.5867C18.4706 25.5368 18.5193 25.4667 18.543 25.3869L18.7744 24.6298ZM18.7744 30.344C18.7987 30.2652 18.8476 30.1963 18.914 30.1473C18.9803 30.0984 19.0606 30.072 19.143 30.072C19.2254 30.072 19.3057 30.0984 19.372 30.1473C19.4384 30.1963 19.4873 30.2652 19.5116 30.344L19.743 31.1011C19.793 31.2654 19.943 31.3782 20.1115 31.3782H20.8987C21.2687 31.3782 21.4272 31.8539 21.133 32.0825L20.4644 32.6011C20.4012 32.6505 20.3546 32.7179 20.3306 32.7945C20.3066 32.871 20.3064 32.953 20.3301 33.0296L20.5773 33.8425C20.6887 34.2068 20.273 34.5025 19.973 34.2711L19.3773 33.8082C19.3103 33.7561 19.2279 33.7278 19.1 ...

# %%
# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')

# Find the table containing the data
table = soup.find('div', id="company-overview-size").find('table', class_='mi-table')

# Initialize data dictionary
data = {'Attribute': [], 'Value': []}

# Find and extract data from the table
rows = table.find_all('tr')
for row in rows:
    columns = row.find_all('td')
    print(columns)
    for column in columns:
        print(column[0])
        print(column[1])
        print(column[2])

    
# for row in rows:
#     columns = row.find_all('td')
#     if len(columns) == 2:
#         attribute = columns[0].get_text(strip=True)
#         value = columns[1].get_text(strip=True)
#         data['Attribute'].append(attribute)
#         data['Value'].append(value)

# # Create a DataFrame from the extracted data
# df = pd.DataFrame(data)

# # Filter the rows to include only 'Market Cap', 'ASX Rank', and 'Sector Rank'
# filtered_df = df[df['Attribute'].isin(['Market Cap', 'ASX Rank', 'Sector Rank'])]

# # Reset the index
# filtered_df = filtered_df.reset_index(drop=True)

# # Print the resulting DataFrame
# print(filtered_df)
# Out:
# [<td>
# <div class="relative">
# <span class="inline-block mr-1">
# Market Cap
# </span>
# <span class="absolute -mt-1 text-normal">
# <a class="xmodal-trigger" data-target="market-cap-explain" href="#" title="Excludes mandatory escrowed shares and foreign shares">
# <img alt="Question Mark Icon" src="https://www.marketindex.com.au/images/icons/question-mark-light.svg"/>
# </a>
# </span>
# </div>
# <div class="xmodal" id="market-cap-explain" name="market-cap-explain">
# <div class="body-content text-center">
# Excludes mandatory escrowed shares and foreign shares.
# </div>
# </div>
# </td>, <td class="text-right"><span class="quoteapi-number quoteapi-value" data-quoteapi="marketCap scale=false">$14,793,759</span></td>]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[38], line 16
#      14 print(columns)
#      15 for column in columns:
# ---> 16     print(column[0])
#      17     print(column[1])
#      18     print(column[2])
#
# File ~\anaconda3\envs\PythonData\Lib\site-packages\bs4\element.py:1573, in Tag.__getitem__(self, key)
#    1570 def __getitem__(self, key):
#    1571     """tag[key] returns the value of the 'key' attribute for the Tag,
#    1572     and throws an exception if it's not there."""
# -> 1573     return self.attrs[key]
#
# KeyError: 0

# %%
fundamentals = soup.find_all('div', class_="sm:w-1/2 lg:w-full sm:pr-4 lg:p-0")
print(fundamentals)
# Out:
# [<div class="sm:w-1/2 lg:w-full sm:pr-4 lg:p-0">
# <h3 class="h3">Key Fundamentals</h3>
# <table class="mi-table">
# <tbody><tr>
# <td>Shares Issued</td>
# <td class="text-right"><span class="quoteapi-number quoteapi-volume" data-quoteapi="sharesIssued">51,907,925</span></td>
# </tr>
# <tr>
# <td>Sector</td>
# <td class="text-right">Basic Materials</td>
# </tr>
# <tr>
# <td>Similar Companies</td>
# <td class="text-right"><a href="https://www.marketindex.com.au/asx/adv">ADV</a> / <a href="https://www.marketindex.com.au/asx/ase">ASE</a> / <a href="https://www.marketindex.com.au/asx/mrz">MRZ</a></td>
# </tr>
# <tr>
# <td>EPS</td>
# <td class="text-right">-$0.044</td>
# </tr>
# <tr>
# <td>DPS</td>
# <td class="text-right">$0.00</td>
# </tr>
# <tr>
# <td>Book Value Per Share</td>
# <td class="text-right">$0.123</td>
# </tr>
# </tbody></table>
# </div>]

# %%
broker_consensus = soup.find_all('div', class_="sm:w-1/2 lg:w-full sm:pl-4 lg:p-0 mt-6 sm:mt-0 lg:mt-6")
print(broker_consensus)
# Out:
# [<div class="sm:w-1/2 lg:w-full sm:pl-4 lg:p-0 mt-6 sm:mt-0 lg:mt-6">
# <h3 class="h3">Broker Consensus</h3>
# <p class="text-sm leading-6">
# SLB is not covered by a major broker, or data from most recent compilation was omitted due
# to not meeting QA guidelines.
# </p>
# </div>]

# %%
<div class="sm:w-1/2 lg:w-1/3 sm:pr-4 mb-6 lg:mb-0">
<h3 class="h3">Share Price Activity (ASX)</h3>
<table class="mi-table">
<tbody><tr>
<td>Last (Price)</td>
<td class="text-right">
<span data-quoteapi="price" class="quoteapi-number quoteapi-price">$45.50</span>
</td>
</tr>
<tr>
<td>Change</td>
<td class="text-right pos" data-quoteapi="changeSignCSS">
<span data-quoteapi="change showNegativeSign=false" class="quoteapi-number quoteapi-price quoteapi-change">0.12</span>
(<span data-quoteapi="pctChange showNegativeSign=true" class="quoteapi-number quoteapi-pct-change">0.26%</span>)
</td>
</tr>
<tr>
<td>Bid / Ask</td>
<td class="text-right">
<span data-quoteapi="bid" class="quoteapi-number quoteapi-price">$45.50</span>
<span>-</span>
<span data-quoteapi="ask" class="quoteapi-number quoteapi-price">$45.51</span>
</td>
</tr>
<tr>
<td>Volume</td>
<td class="text-right"><span data-quoteapi="volume scale=false" class="quoteapi-number quoteapi-volume">6,766,318</span></td>
</tr>
<tr>
<td>Volume (4w avg)</td>
<td class="text-right"><span data-quoteapi="monthAverageVolume scale=false" class="quoteapi-number quoteapi-volume">7,345,298</span></td>
</tr>
<tr>
<td>Turnover</td>
<td class="text-right"><span data-quoteapi="value scale=false" class="quoteapi-number quoteapi-value">$308,576,546</span></td>
</tr>
<tr>
<td>Open</td>
<td class="text-right"><span data-quoteapi="open" class="quoteapi-number quoteapi-price">$45.80</span></td>
</tr>
<tr>
<td>Day Range</td>
<td class="text-right"><span data-quoteapi="low" class="quoteapi-number quoteapi-price">$45.43</span> - <span data-quoteapi="high" class="quoteapi-number quoteapi-price">$45.88</span></td>
</tr>
<tr>
<td>VWAP</td>
<td class="text-right"><span data-quoteapi="vwap" class="quoteapi-number quoteapi-price">$45.61</span></td>
</tr>
<tr>
<td>Prev Close</td>
<td class="text-right"><span data-quoteapi="prevClose" class="quoteapi-number quoteapi-price">$45.38</span></td>
</tr>
<tr>
<td>Last Trade</td>
<td class="text-right"><span data-quoteapi="dateTime format='h:mma DD/MM (z)'">4:12pm 03/11 (AEDT)</span></td>
</tr>
</tbody></table>
</div>

# %%
<div class="sm:w-1/2 lg:w-1/3 sm:pl-4 lg:px-4 mb-6 lg:mb-0">
<h3 class="h3">Performance</h3>
<table class="mi-table">
<tbody><tr>
<td>1 Week</td>
<td class="text-right"><span data-quoteapi="weekPctChange (fullySigned); weekChangeSignCSS" class="quoteapi-number quoteapi-pct-change pos">+1.27%</span></td>
</tr>
<tr>
<td>1 Month</td>
<td class="text-right"><span data-quoteapi="monthPctChange (fullySigned); monthChangeSignCSS" class="quoteapi-number quoteapi-pct-change pos">+2.02%</span></td>
</tr>
<tr>
<td>2023 YTD</td>
<td class="text-right"><span data-quoteapi="ytdPctChange (fullySigned); ytdChangeSignCSS" class="quoteapi-number quoteapi-pct-change neg">-0.28%</span></td>
</tr>
<tr>
<td>1 Year</td>
<td class="text-right"><span data-quoteapi="yearPctChange (fullySigned); yearChangeSignCSS" class="quoteapi-number quoteapi-pct-change pos">+19.80%</span></td>
</tr>
<tr>
<td>vs Sector (1yr)</td>
<td class="text-right">
<span class="text-teal-dark">
+5.80%
</span>
</td>
</tr>
<tr>
<td>vs ASX 200 (1yr)</td>
<td class="text-right">
<span class="text-teal-dark">
+17.91%
</span>
</td>
</tr>
</tbody></table>
<div class="mt-6">
<h3 class="h3">Size</h3>
<div id="company-overview-size">
<table class="mi-table">
<tbody><tr>
<td>
<div class="relative">
<span class="inline-block mr-1">
Market Cap
</span>
<span class="absolute -mt-1 text-normal">
<a href="#" class="xmodal-trigger" data-target="market-cap-explain" title="Excludes mandatory escrowed shares and foreign shares">
<img src="https://www.marketindex.com.au/images/icons/question-mark-light.svg" alt="Question Mark Icon">
</a>
</span>
</div>
<div class="xmodal" id="market-cap-explain" name="market-cap-explain">
<div class="body-content text-center">
Excludes mandatory escrowed shares and foreign shares.
</div>
</div>
</td>
<td class="text-right"><span data-quoteapi="marketCap scale=false" class="quoteapi-number quoteapi-value">$230,627,660,309</span></td>
</tr>
<tr>
<td>ASX Rank</td>
<td class="text-right">1 of 2,408</td>
</tr>
<tr>
<td>Sector Rank</td>
<td class="text-right">1 of 978</td>
</tr>
</tbody></table>
</div>
</div>
</div>

# %%
<div class="sm:w-1/2 lg:w-full sm:pr-4 lg:p-0">
<h3 class="h3">Key Fundamentals</h3>
<table class="mi-table">
<tbody><tr>
<td>Shares Issued</td>
<td class="text-right"><span data-quoteapi="sharesIssued" class="quoteapi-number quoteapi-volume">5,068,739,787</span></td>
</tr>
<tr>
<td>Sector</td>
<td class="text-right">Basic Materials</td>
</tr>
<tr>
<td>Similar Companies</td>
<td class="text-right"><a href="https://www.marketindex.com.au/asx/fmg">FMG</a> / <a href="https://www.marketindex.com.au/asx/rio">RIO</a> / <a href="https://www.marketindex.com.au/asx/nem">NEM</a></td>
</tr>
<tr>
<td>EPS</td>
<td class="text-right">$2.547</td>
</tr>
<tr>
<td>DPS</td>
<td class="text-right">$2.6143</td>
</tr>
<tr>
<td>Book Value Per Share</td>
<td class="text-right">$8.184</td>
</tr>
</tbody></table>
</div>

# %%
<div class="sm:w-1/2 lg:w-full sm:pl-4 lg:p-0 mt-6 sm:mt-0 lg:mt-6">
<h3 class="h3">Broker Consensus</h3>
<table class="mi-table">
<tbody><tr>
<td>Breakdown</td>
<td class="text-right">
<span class="text-teal-dark">11 Buy</span>
· <span class="text-yellow-dark">9 Hold</span>
· <span class="text-red">3 Sell</span>
</td>
</tr>
<tr>
<td>Recommendation</td>
<td class="text-right text-teal-dark">
Buy
</td>
</tr>
<tr>
<td>Last Updated</td>
<td class="text-right">
<a href="https://www.marketindex.com.au/broker-consensus">
01/10/23
</a>
</td>
</tr>
</tbody></table>
</div>
